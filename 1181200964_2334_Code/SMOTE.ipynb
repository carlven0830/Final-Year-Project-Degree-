# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Dataset(LabelEncoder).csv", low_memory=False)
df
# Out:
#       label  file_access  pe_imports  sig_clamav  pe_sec_character  \
# 0         0          764         129         560                81
# 1         0          984         129         560                81
# 2         0         2164        1394         560                77
# 3         0          946         962         560                81
# 4         0         1743        1345         560                77
# ...     ...          ...         ...         ...               ...
# 6027      4          561        1235         560                88
# 6028      4         1341         978         560                88
# 6029      4          561        1235         560                88
# 6030      4         1846         465         560               107
# 6031      4         1846         598         560               107
#
#       sig_antivirus_virustotal  cmd_exec  api_resolv  pe_sec_entropy  \
# 0                         2280       102        1302            1147
# ...

# %%
X = df.iloc[:, 0:65]
y = df['label']

y.value_counts().plot.pie(autopct='%.2f', ylabel='')
y.value_counts()
# Out:
# 1    2020
# 3    2019
# 4    1270
# 2     431
# 0     292
# Name: label, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

smt = SMOTE(random_state = 0) # Define SMOTE method
X_sm, y_sm = smt.fit_resample(X, y) # Fit and apply the transform

y_sm.value_counts().plot.pie(autopct='%.2f', ylabel='')
y_sm.value_counts()
# Out:
# 0    2020
# 1    2020
# 2    2020
# 3    2020
# 4    2020
# Name: label, dtype: int64

# %%
df2 = pd.DataFrame(X_sm)
df2.to_csv('Dataset(SMOTE).csv', index=False)

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=0)
X_ros, y_ros = ros.fit_resample(X, y)

y_ros.value_counts()
# Out:
# 0    2020
# 1    2020
# 2    2020
# 3    2020
# 4    2020
# Name: label, dtype: int64

# %%
df2 = pd.DataFrame(X_sm)
df2.to_csv('Dataset(ROS).csv', index=False)

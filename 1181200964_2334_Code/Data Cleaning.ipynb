# %%
import pandas as pd
import csv
import numpy as np

# %%
df = pd.read_csv("Dataset(Sort).csv", low_memory=False)

# %%
df.iloc[:, 4:150].count().sort_values(ascending=False)
df.isnull().sum()
# Out:
# entityId                             0
# entityType                           0
# event                                0
# eventTime                            0
# file_access                       1618
#                                   ...
# sig_ransomware_message            6026
# sig_cryptam                       6032
# sig_packer_vmprotect              6032
# sig_recon_beacon                  6019
# sig_static_versioninfo_anomaly    6031
# Length: 150, dtype: int64

# %%
df.dropna(axis=1,how="all", inplace=True)
df
# Out:
#       entityId entityType    event                     eventTime  \
# 0          780    content  malware  2016-12-15T09:01:42.068+0000
# 1          824    content  malware  2016-12-15T09:01:43.818+0000
# 2          825    content  malware  2016-12-15T09:01:43.857+0000
# 3          826    content  malware  2016-12-15T09:01:44.085+0000
# 4          679    content  malware  2016-12-15T09:01:36.290+0000
# ...        ...        ...      ...                           ...
# 6027   1577487    content  malware  2017-04-22T16:24:17.276+0000
# 6028   1577776    content  malware  2017-04-22T16:24:30.030+0000
# 6029   1577487    content  malware  2017-04-22T16:24:17.307+0000
# 6030   1577779    content  malware  2017-04-22T16:24:41.248+0000
# 6031   1577596    content  malware  2017-04-22T16:24:10.745+0000
#
#                                             file_access  \
# 0     3d801aa5 76498be8 98e83379 d41d8cd9 913f9c49 9...
# 1     3d801aa5 a12ac23c 98e83379 d41d8cd9 913f9c49 9...
# ...

# %%
df.iloc[:,4:92].count().sort_values(ascending=False)
# Out:
# label                             6032
# str                               6029
# pe_sec_name                       6020
# pe_sec_character                  6020
# pe_sec_entropy                    6020
#                                   ...
# sig_yara_detection                   2
# sig_antiav_detectreg                 2
# sig_network_torgateway               1
# sig_antivm_vbox_files                1
# sig_static_versioninfo_anomaly       1
# Length: 88, dtype: int64

# %%
df3 = df.drop([
    'sig_stealth_webhistory',
    'sig_infostealer_browser',
    'sig_ransomware_file_modifications',
    'sig_bcdedit_command',
    'sig_driver_load',
    'sig_antisandbox_cuckoocrash',
    'sig_ransomware_message',
    'sig_persistence_service',
    'sig_persistence_ads',
    'sig_ipc_namedpipe',
    'sig_internet_dropper',
    'sig_critical_process',
    'sig_antiav_detectfile',
    'sig_antisandbox_suspend',
    'sig_recon_checkip',
    'sig_modifies_hostfile',
    'sig_Threat Crowd Resolutions',
    'sig_banker_zeus_url',
    'sig_yara_detection',
    'sig_antiav_detectreg',
    'sig_network_torgateway',
    'sig_antivm_vbox_files',
    'sig_static_versioninfo_anomaly',
    ], 
    axis=1, inplace=False)

df3.iloc[:, 4:69].count().sort_values(ascending=False)
# Out:
# label                        6032
# str                          6029
# pe_sec_character             6020
# pe_sec_entropy               6020
# pe_sec_name                  6020
#                              ...
# sig_infostealer_bitcoin        17
# sig_disables_browser_warn      17
# sig_removes_zoneid_ads         15
# sig_recon_beacon               13
# sig_creates_largekey           10
# Length: 65, dtype: int64

# %%
df2 = df3.fillna("NA")
df2.isnull().sum()
# Out:
# entityId                   0
# entityType                 0
# event                      0
# eventTime                  0
# file_access                0
#                           ..
# sig_creates_largekey       0
# sig_infostealer_bitcoin    0
# sig_static_detection       0
# sig_antiav_servicestop     0
# sig_recon_beacon           0
# Length: 69, dtype: int64

# %%
move_column = df2.pop('label')

df2.insert(4, 'label', move_column)
df2
# Out:
#       entityId entityType    event                     eventTime  \
# 0          780    content  malware  2016-12-15T09:01:42.068+0000
# 1          824    content  malware  2016-12-15T09:01:43.818+0000
# 2          825    content  malware  2016-12-15T09:01:43.857+0000
# 3          826    content  malware  2016-12-15T09:01:44.085+0000
# 4          679    content  malware  2016-12-15T09:01:36.290+0000
# ...        ...        ...      ...                           ...
# 6027   1577487    content  malware  2017-04-22T16:24:17.276+0000
# 6028   1577776    content  malware  2017-04-22T16:24:30.030+0000
# 6029   1577487    content  malware  2017-04-22T16:24:17.307+0000
# 6030   1577779    content  malware  2017-04-22T16:24:41.248+0000
# 6031   1577596    content  malware  2017-04-22T16:24:10.745+0000
#
#               label                                        file_access  \
# 0              APT1  3d801aa5 76498be8 98e83379 d41d8cd9 913f9c49 9...
# ...

# %%
df2.to_csv('Dataset(CleanNA).csv', index=False)

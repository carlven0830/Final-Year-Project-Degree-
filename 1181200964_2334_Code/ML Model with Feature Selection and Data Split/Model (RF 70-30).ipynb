# %%
import pandas as pd
import csv
import numpy as np

df = pd.read_csv("Dataset(SMOTE).csv", low_memory=False)
df
# Out:
#        label  file_access  pe_imports  sig_clamav  pe_sec_character  \
# 0          0          764         129         560                81
# 1          0          984         129         560                81
# 2          0         2164        1394         560                77
# 3          0          946         962         560                81
# 4          0         1743        1345         560                77
# ...      ...          ...         ...         ...               ...
# 10095      4          666         561         560               106
# 10096      4         1099         427         560               107
# 10097      4         1856        1407         560                81
# 10098      4         1846        1373         560               102
# 10099      4         1256        1134         560                98
#
#        sig_antivirus_virustotal  cmd_exec  api_resolv  pe_sec_entropy  \
# 0                          2280       102        1302            1147
# 1                          2018       112        1302            1147
# 2                          2018       541         237             124
# 3                          2214       527        1212             183
# 4                           216       144         634              73
# ...                         ...       ...         ...             ...
# 10095                       852       541         634            2102
# 10096                      2018       541         634             309
# 10097                      1573       541         639            1626
# 10098                       331       541         634            1354
# 10099                        73       541         634            1269
#
#        pe_sec_name  ...  sig_antianalysis_detectfile  sig_network_cnc_http  \
# 0              211  ...                            2                    12
# 1              211  ...                            2                    12
# 2              207  ...                            2                    12
# 3              211  ...                            2                    12
# 4              207  ...                            2                    12
# ...            ...  ...                          ...                   ...
# 10095          232  ...                            2                    12
# 10096          233  ...                            2                    12
# 10097          211  ...                            2                    12
# 10098          230  ...                            2                    12
# 10099          227  ...                            2                    12
#
#        sig_removes_zoneid_ads  sig_downloader_cabby  sig_sniffer_winpcap  \
# 0                           5                     2                    2
# 1                           5                     2                    2
# 2                           5                     2                    2
# 3                           5                     2                    2
# 4                           5                     2                    2
# ...                       ...                   ...                  ...
# 10095                       5                     2                    2
# 10096                       5                     2                    2
# 10097                       5                     2                    2
# 10098                       5                     2                    2
# 10099                       5                     2                    2
#
#        sig_creates_largekey  sig_infostealer_bitcoin  sig_static_detection  \
# 0                         3                        0                   231
# 1                         3                        0                   231
# 2                         3                        0                   231
# 3                         3                        0                   231
# 4                         3                        0                   231
# ...                     ...                      ...                   ...
# 10095                     3                        0                   230
# 10096                     3                        0                   231
# 10097                     3                        0                    71
# 10098                     3                        0                   118
# 10099                     3                        0                   196
#
#        sig_antiav_servicestop  sig_recon_beacon
# 0                           4                11
# 1                           4                11
# 2                           4                11
# 3                           4                11
# 4                           4                11
# ...                       ...               ...
# 10095                       4                11
# 10096                       4                11
# 10097                       4                11
# 10098                       4                11
# 10099                       4                11
#
# [10100 rows x 65 columns]

# %%
from sklearn.model_selection import train_test_split

# Separating the features from the target variable
X = df.iloc[:, 1:65]
y = df['label']

# Splitting the data into a train and a dev set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .3, random_state = 0)

# %%
from boruta import BorutaPy
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(criterion='gini',max_depth=10, max_features='sqrt',
                             min_samples_split=10, n_estimators=400, random_state=0)

boruta_selector = BorutaPy(rfc, n_estimators='auto', verbose=2, random_state=0)

boruta_selector.fit(np.array(X_train), np.array(y_train))
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	64
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	64
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	64
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	64
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	64
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	64
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	64
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	25
# Iteration: 	9 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	25
# Iteration: 	10 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	25
# Iteration: 	11 / 100
# Confirmed: 	31
# Tentative: 	8
# Rejected: 	25
# Iteration: 	12 / 100
# Confirmed: 	32
# Tentative: 	7
# Rejected: 	25
# Iteration: 	13 / 100
# Confirmed: 	32
# Tentative: 	7
# Rejected: 	25
# Iteration: 	14 / 100
# Confirmed: 	32
# Tentative: 	6
# Rejected: 	26
# Iteration: 	15 / 100
# Confirmed: 	32
# Tentative: 	6
# Rejected: 	26
# Iteration: 	16 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	17 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	18 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	19 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	20 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	21 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	22 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	23 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	24 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	25 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	26 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	27 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	28 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	29 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	30 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	31 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	32 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	33 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	34 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	35 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	36 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	37 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	38 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	39 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	40 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	41 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	42 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	43 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	44 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	45 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	46 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	47 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	48 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	49 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	50 / 100
# Confirmed: 	32
# Tentative: 	4
# Rejected: 	28
# Iteration: 	51 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	52 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	53 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	54 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	55 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	56 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	57 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	58 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	59 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	60 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	61 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	62 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	63 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	64 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	65 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	66 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	67 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	68 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	69 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	70 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	71 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	72 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	73 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	74 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	75 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	76 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	77 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	78 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	79 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	80 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	81 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	82 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	83 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	84 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	85 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	86 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	87 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	88 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	89 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	90 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	91 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	92 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	93 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	94 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	95 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	96 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	97 / 100
# Confirmed: 	32
# Tentative: 	3
# Rejected: 	29
# Iteration: 	98 / 100
# Confirmed: 	32
# Tentative: 	2
# Rejected: 	30
# Iteration: 	99 / 100
# Confirmed: 	32
# Tentative: 	2
# Rejected: 	30
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	32
# Tentative: 	1
# Rejected: 	30
# BorutaPy(estimator=RandomForestClassifier(max_depth=10, min_samples_split=10,
#                                           n_estimators=82,
#                                           random_state=RandomState(MT19937) at 0x2179E5BD140),
#          n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x2179E5BD140, verbose=2)

# %%
# Using the BorutaPy object to transform the features in the dataset.
X_important_train = boruta_selector.transform(np.array(X_train))
X_important_test = boruta_selector.transform(np.array(X_test))

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

rf_boruta = RandomForestClassifier(random_state=0)

# Defining search space from which grid serch will select a model which will give the best result.
param_grid = {
    'criterion': ['gini', 'entropy'],
    'n_estimators': [200, 300, 400],
    'max_features': ['sqrt', 'log2'],
    'max_depth': [8, 10, 12],
    'min_samples_split': [2, 5, 10]
}

# Making an object grid_GBC for GridSearchCV and fitting the dataset
grid_rf = GridSearchCV(rf_boruta, param_grid, refit=True, n_jobs=-1, cv=10, verbose=3, scoring='accuracy')
grid_rf.fit(X_important_train, y_train)

# Print best parameters and accuracy score
print("Best parameters found: ", grid_rf.best_params_)
print("Best accuracy score found: {:.4f}".format(grid_rf.best_score_))
# Out:
# Fitting 10 folds for each of 108 candidates, totalling 1080 fits
# Best parameters found:  {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 400}
# Best accuracy score found: 0.8372

# %%
#  Give best model as a result
rf_model = grid_rf.best_estimator_
rf_model
# Out:
# RandomForestClassifier(max_depth=10, min_samples_split=10, n_estimators=400,
#                        random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier

# Instantiate model
rfc1 = RandomForestClassifier(criterion='gini',max_depth=10, max_features='sqrt',
                              min_samples_split=10, n_estimators=400, random_state=0)

# Train the model on training data
rfc1.fit(X_important_train, y_train)

# Use the forest's predict method on the test data
rfc_predict = rfc1.predict(X_important_test)

# Export the predicted values
np.savetxt("RF_Balanced(70-30).csv", rfc_predict, delimiter=",")

# %%
from sklearn import metrics

# Accuracy
print(metrics.accuracy_score(y_test, rfc_predict))
# Precision
print(metrics.precision_score(y_test, rfc_predict, average='macro'))
# Recall
print(metrics.recall_score(y_test, rfc_predict, average='macro'))
# F1 Score
print(metrics.f1_score(y_test, rfc_predict, average='macro'))
# Out:
# 0.838943894389439
# 0.8414951841397054
# 0.8370423440979703
# 0.8358791776794325

# %%
import matplotlib.pyplot as plt

# Confusion Matrix
conf_matrix = metrics.confusion_matrix(y_test, rfc_predict, normalize = 'true')

fig, ax = plt.subplots(figsize=(8, 6))
caxes = ax.matshow(conf_matrix, cmap=plt.cm.Blues)
fig.colorbar(caxes)
fmt = '.2f'
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=format(conf_matrix[i, j], fmt), va='center', ha='center', size='xx-large')

a=ax.get_xticks().tolist()
a[1]='APT1'
a[2]='Crypto'
a[3]='Locker'
a[4]='Zeus'
a[5]='shadowbrokers'

b=ax.get_yticks().tolist()
b[1]='APT1'
b[2]='Crypto'
b[3]='Locker'
b[4]='Zeus'
b[5]='shadowbrokers'
ax.set_xticklabels(a)
ax.set_yticklabels(b)

plt.xlabel('Predicted Values', fontsize=12)
plt.ylabel('Actual Values', fontsize=12)
plt.gca().xaxis.tick_bottom()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17468\3015791322.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(a)
# C:\Users\user\AppData\Local\Temp\ipykernel_17468\3015791322.py:28: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(b)

# %%
from sklearn.ensemble import RandomForestClassifier

# Instantiate model with 100 decision trees
rfc2 = RandomForestClassifier(criterion='gini',max_depth=10, max_features='sqrt',
                              min_samples_split=10, n_estimators=400, random_state=0)

# Train the model on training data
rfc2.fit(X_train, y_train)

# Use the forest's predict method on the test data
rfc2_predict = rfc2.predict(X_test)

# Export the predicted values
np.savetxt("RF_Imbalanced(70-30).csv", rfc2_predict, delimiter=",")

# %%
from sklearn import metrics

# Accuracy
print(metrics.accuracy_score(y_test, rfc2_predict))
# Precision
print(metrics.precision_score(y_test, rfc2_predict, average='macro'))
# Recall
print(metrics.recall_score(y_test, rfc2_predict, average='macro'))
# F1 Score
print(metrics.f1_score(y_test, rfc2_predict, average='macro'))
# Out:
# 0.835973597359736
# 0.8367217889930421
# 0.8341541730903066
# 0.8325669498750988

# %%
import matplotlib.pyplot as plt

# Confusion Matrix
conf_matrix = metrics.confusion_matrix(y_test, rfc2_predict, normalize = 'true')

fig, ax = plt.subplots(figsize=(8, 6))
caxes = ax.matshow(conf_matrix, cmap=plt.cm.Blues)
fig.colorbar(caxes)
fmt = '.2f'
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=format(conf_matrix[i, j], fmt), va='center', ha='center', size='xx-large')

a=ax.get_xticks().tolist()
a[1]='APT1'
a[2]='Crypto'
a[3]='Locker'
a[4]='Zeus'
a[5]='shadowbrokers'

b=ax.get_yticks().tolist()
b[1]='APT1'
b[2]='Crypto'
b[3]='Locker'
b[4]='Zeus'
b[5]='shadowbrokers'
ax.set_xticklabels(a)
ax.set_yticklabels(b)

plt.xlabel('Predicted Values', fontsize=12)
plt.ylabel('Actual Values', fontsize=12)
plt.gca().xaxis.tick_bottom()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17468\106375199.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(a)
# C:\Users\user\AppData\Local\Temp\ipykernel_17468\106375199.py:28: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(b)

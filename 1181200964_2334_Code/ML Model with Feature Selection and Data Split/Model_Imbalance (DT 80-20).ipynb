# %%
import pandas as pd
import csv
import numpy as np

df = pd.read_csv("Dataset(LabelEncoder).csv", low_memory=False)
df
# Out:
#       label  file_access  pe_imports  sig_clamav  pe_sec_character  \
# 0         0          764         129         560                81
# 1         0          984         129         560                81
# 2         0         2164        1394         560                77
# 3         0          946         962         560                81
# 4         0         1743        1345         560                77
# ...     ...          ...         ...         ...               ...
# 6027      4          561        1235         560                88
# 6028      4         1341         978         560                88
# 6029      4          561        1235         560                88
# 6030      4         1846         465         560               107
# 6031      4         1846         598         560               107
#
#       sig_antivirus_virustotal  cmd_exec  api_resolv  pe_sec_entropy  \
# 0                         2280       102        1302            1147
# ...

# %%
from sklearn.model_selection import train_test_split

# Separating the features from the target variable
X = df.iloc[:, 1:65]
y = df['label']

# Splitting the data into a train and a dev set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 0)

# %%
from boruta import BorutaPy
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(criterion='gini',max_depth=10, max_features='sqrt',
                             min_samples_split=10, n_estimators=300, random_state=0)

boruta_selector = BorutaPy(rfc, n_estimators='auto', verbose=2, random_state=0)

boruta_selector.fit(np.array(X_train), np.array(y_train))
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	64
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	64
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	64
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	64
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	64
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	64
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	64
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	23
# Tentative: 	4
# Rejected: 	37
# Iteration: 	9 / 100
# Confirmed: 	23
# Tentative: 	4
# Rejected: 	37
# Iteration: 	10 / 100
# Confirmed: 	23
# Tentative: 	4
# Rejected: 	37
# Iteration: 	11 / 100
# Confirmed: 	23
# Tentative: 	4
# Rejected: 	37
# Iteration: 	12 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	40
# Iteration: 	13 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	40
# Iteration: 	14 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	40
# ...

# %%
# Using the BorutaPy object to transform the features in the dataset.
X_important_train = boruta_selector.transform(np.array(X_train))
X_important_test = boruta_selector.transform(np.array(X_test))

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# Create Decision Tree classifier object
dt_boruta = DecisionTreeClassifier(random_state=0)

# Defining the search space from which GridSearchCV will select the best model
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [10, 12, 15],
    'min_samples_split': [2, 5, 10],
    'max_features': ['sqrt', 'log2']
}

grid_dt = GridSearchCV(dt_boruta, param_grid, refit=True, n_jobs=-1, cv=10, verbose=3, scoring='accuracy')

# Train Decision Tree classifier
grid_dt.fit(X_important_train, y_train)

# Best parameters and score
# Print best parameters and accuracy score
print("Best parameters found: ", grid_dt.best_params_)
print("Best accuracy score found: {:.4f}".format(grid_dt.best_score_))
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# Best parameters found:  {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_split': 5}
# Best accuracy score found: 0.6860

# %%
#  Give best model as a result
dt_model = grid_dt.best_estimator_
dt_model
# Out:
# DecisionTreeClassifier(max_depth=15, max_features='sqrt', min_samples_split=5,
#                        random_state=0)

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# Create Decision Tree classifer object
dt1 = DecisionTreeClassifier(criterion='gini', max_depth=15, min_samples_split=5,
                             max_features='sqrt', random_state=0)

# Train the model on training data
dt1.fit(X_important_train, y_train)

# Use the forest's predict method on the test data
dt_predict = dt1.predict(X_important_test)

# Export the predicted values
np.savetxt("DT_Imbalanced(80-20).csv", dt_predict, delimiter=",")

# %%
from sklearn import metrics

# Accuracy
print(metrics.accuracy_score(y_test, dt_predict))
# Precision
print(metrics.precision_score(y_test, dt_predict, average='weighted'))
# Recall
print(metrics.recall_score(y_test, dt_predict, average='weighted'))
# F1 Score
print(metrics.f1_score(y_test, dt_predict, average='weighted'))
# Out:
# 0.6743993371996686
# 0.6714603756611628
# 0.6743993371996686
# 0.6713921635335532

# %%
import matplotlib.pyplot as plt

# Confusion Matrix
conf_matrix = metrics.confusion_matrix(y_test, dt_predict, normalize = 'true')

fig, ax = plt.subplots(figsize=(8, 6))
caxes = ax.matshow(conf_matrix, cmap=plt.cm.Blues)
fig.colorbar(caxes)
fmt = '.2f'
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=format(conf_matrix[i, j], fmt), va='center', ha='center', size='xx-large')

a=ax.get_xticks().tolist()
a[1]='APT1'
a[2]='Crypto'
a[3]='Locker'
a[4]='Zeus'
a[5]='shadowbrokers'

b=ax.get_yticks().tolist()
b[1]='APT1'
b[2]='Crypto'
b[3]='Locker'
b[4]='Zeus'
b[5]='shadowbrokers'
ax.set_xticklabels(a)
ax.set_yticklabels(b)

plt.xlabel('Predicted Values', fontsize=12)
plt.ylabel('Actual Values', fontsize=12)
plt.gca().xaxis.tick_bottom()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21448\1119618409.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(a)
# C:\Users\user\AppData\Local\Temp\ipykernel_21448\1119618409.py:28: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(b)

# %%
# Create Decision Tree classifier object
dt2_boruta = DecisionTreeClassifier(random_state=0)

# Defining the search space from which GridSearchCV will select the best model
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [10, 12, 15],
    'min_samples_split': [2, 5, 10],
    'max_features': ['sqrt', 'log2']
}
grid_dt2 = GridSearchCV(dt2_boruta, param_grid, refit=True, n_jobs=-1, cv=10, verbose=3, scoring='accuracy')

# Train Decision Tree classifier
grid_dt2.fit(X_train, y_train)

# Best parameters and score
# Print best parameters and accuracy score
print("Best parameters found: ", grid_dt2.best_params_)
print("Best accuracy score found: {:.4f}".format(grid_dt2.best_score_))
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# Best parameters found:  {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 10}
# Best accuracy score found: 0.6725

# %%
# Instantiate model with 100 decision trees
dt2 = DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_split=10,
                             max_features='sqrt', random_state=0)

# Train the model on training data
dt2.fit(X_train, y_train)

# Use the forest's predict method on the test data
dt2_predict = dt2.predict(X_test)

# Export the predicted values
np.savetxt("DT_ImbalancedXBoruta(80-20).csv", dt2_predict, delimiter=",")

# %%
from sklearn import metrics

# Accuracy
print(metrics.accuracy_score(y_test, dt2_predict))
# Precision
print(metrics.precision_score(y_test, dt2_predict, average='weighted'))
# Recall
print(metrics.recall_score(y_test, dt2_predict, average='weighted'))
# F1 Score
print(metrics.f1_score(y_test, dt2_predict, average='weighted'))
# Out:
# 0.6014913007456504
# 0.6212429906557909
# 0.6014913007456504
# 0.6007133330659574

# %%
import matplotlib.pyplot as plt

# Confusion Matrix
conf_matrix = metrics.confusion_matrix(y_test, dt2_predict, normalize = 'true')

fig, ax = plt.subplots(figsize=(8, 6))
caxes = ax.matshow(conf_matrix, cmap=plt.cm.Blues)
fig.colorbar(caxes)
fmt = '.2f'
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=format(conf_matrix[i, j], fmt), va='center', ha='center', size='xx-large')

a=ax.get_xticks().tolist()
a[1]='APT1'
a[2]='Crypto'
a[3]='Locker'
a[4]='Zeus'
a[5]='shadowbrokers'

b=ax.get_yticks().tolist()
b[1]='APT1'
b[2]='Crypto'
b[3]='Locker'
b[4]='Zeus'
b[5]='shadowbrokers'
ax.set_xticklabels(a)
ax.set_yticklabels(b)

plt.xlabel('Predicted Values', fontsize=12)
plt.ylabel('Actual Values', fontsize=12)
plt.gca().xaxis.tick_bottom()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21448\91186897.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(a)
# C:\Users\user\AppData\Local\Temp\ipykernel_21448\91186897.py:28: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(b)
